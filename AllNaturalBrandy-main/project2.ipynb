# %%
# !psql -c "\i /home/jupyter/pagila/pagila-schema.sql"
# Out:
# psql:/home/jupyter/pagila/pagila-schema.sql:8: NOTICE:  drop cascades to 47 other objects
# DETAIL:  drop cascades to type pagila.mpaa_rating
# drop cascades to type pagila.year
# drop cascades to function pagila._group_concat(text,text)
# drop cascades to function pagila.film_in_stock(integer,integer)
# drop cascades to function pagila.film_not_in_stock(integer,integer)
# drop cascades to function pagila.get_customer_balance(integer,timestamp with time zone)
# drop cascades to function pagila.inventory_held_by_customer(integer)
# drop cascades to function pagila.inventory_in_stock(integer)
# drop cascades to function pagila.last_day(timestamp with time zone)
# drop cascades to function pagila.last_updated()
# drop cascades to sequence pagila.customer_customer_id_seq
# drop cascades to table pagila.customer
# drop cascades to function pagila.rewards_report(integer,numeric)
# drop cascades to function pagila.group_concat(text)
# drop cascades to sequence pagila.actor_actor_id_seq
# ...

# %%
# !psql -c "\i /home/jupyter/pagila/pagila-insert-data.sql"
# Out:
# SET
# SET
# SET
# SET
# SET
# SET
# SET
# SET
# SET
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# INSERT 0 1
# ...

# %%
# !psql -c "\d pagila.actor"
# Out:
#                                               Table "pagila.actor"
#    Column    |           Type           | Collation | Nullable |                    Default
# -------------+--------------------------+-----------+----------+------------------------------------------------
#  actor_id    | integer                  |           | not null | nextval('pagila.actor_actor_id_seq'::regclass)
#  first_name  | text                     |           | not null |
#  last_name   | text                     |           | not null |
#  last_update | timestamp with time zone |           | not null | now()
# Indexes:
#     "actor_pkey" PRIMARY KEY, btree (actor_id)
#     "idx_actor_last_name" btree (last_name)
# Referenced by:
#     TABLE "pagila.film_actor" CONSTRAINT "film_actor_actor_id_fkey" FOREIGN KEY (actor_id) REFERENCES pagila.actor(actor_id) ON UPDATE CASCADE ON DELETE RESTRICT
# Triggers:
#     last_updated BEFORE UPDATE ON pagila.actor FOR EACH ROW EXECUTE PROCEDURE pagila.last_updated()

# %%
# !psql -c "SHOW tables"
# Out:
# ERROR:  unrecognized configuration parameter "tables"

# %%
# !psql -c "\d *.*"
# Out:
#                         View "information_schema._pg_foreign_data_wrappers"
#             Column             |               Type                | Collation | Nullable | Default
# -------------------------------+-----------------------------------+-----------+----------+---------
#  oid                           | oid                               |           |          |
#  fdwowner                      | oid                               |           |          |
#  fdwoptions                    | text[]                            |           |          |
#  foreign_data_wrapper_catalog  | information_schema.sql_identifier |           |          |
#  foreign_data_wrapper_name     | information_schema.sql_identifier |           |          |
#  authorization_identifier      | information_schema.sql_identifier |           |          |
#  foreign_data_wrapper_language | information_schema.character_data |           |          |
#
# ...

# %%
# !psql -c "\d pagila.actor"
# Out:
#                                               Table "pagila.actor"
#    Column    |           Type           | Collation | Nullable |                    Default
# -------------+--------------------------+-----------+----------+------------------------------------------------
#  actor_id    | integer                  |           | not null | nextval('pagila.actor_actor_id_seq'::regclass)
#  first_name  | text                     |           | not null |
#  last_name   | text                     |           | not null |
#  last_update | timestamp with time zone |           | not null | now()
# Indexes:
#     "actor_pkey" PRIMARY KEY, btree (actor_id)
#     "idx_actor_last_name" btree (last_name)
# Referenced by:
#     TABLE "pagila.film_actor" CONSTRAINT "film_actor_actor_id_fkey" FOREIGN KEY (actor_id) REFERENCES pagila.actor(actor_id) ON UPDATE CASCADE ON DELETE RESTRICT
# Triggers:
#     last_updated BEFORE UPDATE ON pagila.actor FOR EACH ROW EXECUTE PROCEDURE pagila.last_updated()

# %%
# !psql -c "\d pagila.address"
# Out:
#                                                Table "pagila.address"
#    Column    |           Type           | Collation | Nullable |                      Default
# -------------+--------------------------+-----------+----------+----------------------------------------------------
#  address_id  | integer                  |           | not null | nextval('pagila.address_address_id_seq'::regclass)
#  address     | text                     |           | not null |
#  address2    | text                     |           |          |
#  district    | text                     |           | not null |
#  city_id     | smallint                 |           | not null |
#  postal_code | text                     |           |          |
#  phone       | text                     |           | not null |
#  last_update | timestamp with time zone |           | not null | now()
# Indexes:
#     "address_pkey" PRIMARY KEY, btree (address_id)
#     "idx_fk_city_id" btree (city_id)
# ...

# %%
# !psql -c "\d pagila.category"
# Out:
#                                                Table "pagila.category"
#    Column    |           Type           | Collation | Nullable |                       Default
# -------------+--------------------------+-----------+----------+------------------------------------------------------
#  category_id | integer                  |           | not null | nextval('pagila.category_category_id_seq'::regclass)
#  name        | text                     |           | not null |
#  last_update | timestamp with time zone |           | not null | now()
# Indexes:
#     "category_pkey" PRIMARY KEY, btree (category_id)
# Referenced by:
#     TABLE "pagila.film_category" CONSTRAINT "film_category_category_id_fkey" FOREIGN KEY (category_id) REFERENCES pagila.category(category_id) ON UPDATE CASCADE ON DELETE RESTRICT
# Triggers:
#     last_updated BEFORE UPDATE ON pagila.category FOR EACH ROW EXECUTE PROCEDURE pagila.last_updated()

# %%
# !psql -c "\d pagila.city"
# Out:
#                                              Table "pagila.city"
#    Column    |           Type           | Collation | Nullable |                   Default
# -------------+--------------------------+-----------+----------+----------------------------------------------
#  city_id     | integer                  |           | not null | nextval('pagila.city_city_id_seq'::regclass)
#  city        | text                     |           | not null |
#  country_id  | smallint                 |           | not null |
#  last_update | timestamp with time zone |           | not null | now()
# Indexes:
#     "city_pkey" PRIMARY KEY, btree (city_id)
#     "idx_fk_country_id" btree (country_id)
# Foreign-key constraints:
#     "city_country_id_fkey" FOREIGN KEY (country_id) REFERENCES pagila.country(country_id) ON UPDATE CASCADE ON DELETE RESTRICT
# Referenced by:
# ...

# %%
# !psql -c "\d pagila.country"
# Out:
#                                                Table "pagila.country"
#    Column    |           Type           | Collation | Nullable |                      Default
# -------------+--------------------------+-----------+----------+----------------------------------------------------
#  country_id  | integer                  |           | not null | nextval('pagila.country_country_id_seq'::regclass)
#  country     | text                     |           | not null |
#  last_update | timestamp with time zone |           | not null | now()
# Indexes:
#     "country_pkey" PRIMARY KEY, btree (country_id)
# Referenced by:
#     TABLE "pagila.city" CONSTRAINT "city_country_id_fkey" FOREIGN KEY (country_id) REFERENCES pagila.country(country_id) ON UPDATE CASCADE ON DELETE RESTRICT
# Triggers:
#     last_updated BEFORE UPDATE ON pagila.country FOR EACH ROW EXECUTE PROCEDURE pagila.last_updated()

# %%
# !psql -c "\d pagila.customer"
# Out:
#                                                 Table "pagila.customer"
#    Column    |           Type           | Collation | Nullable |                        Default
# -------------+--------------------------+-----------+----------+-------------------------------------------------------
#  customer_id | integer                  |           | not null | nextval('pagila.customer_customer_id_seq1'::regclass)
#  store_id    | smallint                 |           | not null |
#  first_name  | text                     |           | not null |
#  last_name   | text                     |           | not null |
#  email       | text                     |           |          |
#  address_id  | smallint                 |           | not null |
#  activebool  | boolean                  |           | not null | true
#  create_date | date                     |           | not null | ('now'::text)::date
#  last_update | timestamp with time zone |           |          | now()
# ...

# %%
# !psql -c "\d pagila.film"
# Out:
#                                                   Table "pagila.film"
#         Column        |           Type           | Collation | Nullable |                   Default
# ----------------------+--------------------------+-----------+----------+----------------------------------------------
#  film_id              | integer                  |           | not null | nextval('pagila.film_film_id_seq'::regclass)
#  title                | text                     |           | not null |
#  description          | text                     |           |          |
#  release_year         | pagila.year              |           |          |
#  language_id          | smallint                 |           | not null |
#  original_language_id | smallint                 |           |          |
#  rental_duration      | smallint                 |           | not null | 3
#  rental_rate          | numeric(4,2)             |           | not null | 4.99
# ...

# %%
# !psql -c "\d pagila.film_actor"
# Out:
#                         Table "pagila.film_actor"
#    Column    |           Type           | Collation | Nullable | Default
# -------------+--------------------------+-----------+----------+---------
#  actor_id    | smallint                 |           | not null |
#  film_id     | smallint                 |           | not null |
#  last_update | timestamp with time zone |           | not null | now()
# Indexes:
#     "film_actor_pkey" PRIMARY KEY, btree (actor_id, film_id)
#     "idx_fk_film_id" btree (film_id)
# Foreign-key constraints:
#     "film_actor_actor_id_fkey" FOREIGN KEY (actor_id) REFERENCES pagila.actor(actor_id) ON UPDATE CASCADE ON DELETE RESTRICT
#     "film_actor_film_id_fkey" FOREIGN KEY (film_id) REFERENCES pagila.film(film_id) ON UPDATE CASCADE ON DELETE RESTRICT
# Triggers:
#     last_updated BEFORE UPDATE ON pagila.film_actor FOR EACH ROW EXECUTE PROCEDURE pagila.last_updated()

# %%
# !psql -c "\d pagila.film_category"
# Out:
#                       Table "pagila.film_category"
#    Column    |           Type           | Collation | Nullable | Default
# -------------+--------------------------+-----------+----------+---------
#  film_id     | smallint                 |           | not null |
#  category_id | smallint                 |           | not null |
#  last_update | timestamp with time zone |           | not null | now()
# Indexes:
#     "film_category_pkey" PRIMARY KEY, btree (film_id, category_id)
# Foreign-key constraints:
#     "film_category_category_id_fkey" FOREIGN KEY (category_id) REFERENCES pagila.category(category_id) ON UPDATE CASCADE ON DELETE RESTRICT
#     "film_category_film_id_fkey" FOREIGN KEY (film_id) REFERENCES pagila.film(film_id) ON UPDATE CASCADE ON DELETE RESTRICT
# Triggers:
#     last_updated BEFORE UPDATE ON pagila.film_category FOR EACH ROW EXECUTE PROCEDURE pagila.last_updated()

# %%
# !psql -c "\d pagila.inventory"
# Out:
#                                                 Table "pagila.inventory"
#     Column    |           Type           | Collation | Nullable |                        Default
# --------------+--------------------------+-----------+----------+--------------------------------------------------------
#  inventory_id | integer                  |           | not null | nextval('pagila.inventory_inventory_id_seq'::regclass)
#  film_id      | smallint                 |           | not null |
#  store_id     | smallint                 |           | not null |
#  last_update  | timestamp with time zone |           | not null | now()
# Indexes:
#     "inventory_pkey" PRIMARY KEY, btree (inventory_id)
#     "idx_store_id_film_id" btree (store_id, film_id)
# Foreign-key constraints:
#     "inventory_film_id_fkey" FOREIGN KEY (film_id) REFERENCES pagila.film(film_id) ON UPDATE CASCADE ON DELETE RESTRICT
# ...

# %%
# !psql -c "\d pagila.language"
# Out:
#                                                Table "pagila.language"
#    Column    |           Type           | Collation | Nullable |                       Default
# -------------+--------------------------+-----------+----------+------------------------------------------------------
#  language_id | integer                  |           | not null | nextval('pagila.language_language_id_seq'::regclass)
#  name        | character(20)            |           | not null |
#  last_update | timestamp with time zone |           | not null | now()
# Indexes:
#     "language_pkey" PRIMARY KEY, btree (language_id)
# Referenced by:
#     TABLE "pagila.film" CONSTRAINT "film_language_id_fkey" FOREIGN KEY (language_id) REFERENCES pagila.language(language_id) ON UPDATE CASCADE ON DELETE RESTRICT
#     TABLE "pagila.film" CONSTRAINT "film_original_language_id_fkey" FOREIGN KEY (original_language_id) REFERENCES pagila.language(language_id) ON UPDATE CASCADE ON DELETE RESTRICT
# Triggers:
# ...

# %%
# !psql -c "\d pagila.payment"
# Out:
#                                                Table "pagila.payment"
#     Column    |           Type           | Collation | Nullable |                      Default
# --------------+--------------------------+-----------+----------+----------------------------------------------------
#  payment_id   | integer                  |           | not null | nextval('pagila.payment_payment_id_seq'::regclass)
#  customer_id  | smallint                 |           | not null |
#  staff_id     | smallint                 |           | not null |
#  rental_id    | integer                  |           | not null |
#  amount       | numeric(5,2)             |           | not null |
#  payment_date | timestamp with time zone |           | not null |
# Indexes:
#     "idx_fk_customer_id" btree (customer_id)
#     "idx_fk_staff_id" btree (staff_id)

# %%
# !psql -c "\d pagila.payment_p2020_01"
# Out:
# Did not find any relation named "pagila.payment_p2020_01".

# %%
# !psql -c "\d pagila.payment_p2020_02"
# Out:
# Did not find any relation named "pagila.payment_p2020_02".

# %%
# !psql -c "\d pagila.rental"
# Out:
#                                                Table "pagila.rental"
#     Column    |           Type           | Collation | Nullable |                     Default
# --------------+--------------------------+-----------+----------+--------------------------------------------------
#  rental_id    | integer                  |           | not null | nextval('pagila.rental_rental_id_seq'::regclass)
#  rental_date  | timestamp with time zone |           | not null |
#  inventory_id | integer                  |           | not null |
#  customer_id  | smallint                 |           | not null |
#  return_date  | timestamp with time zone |           |          |
#  staff_id     | smallint                 |           | not null |
#  last_update  | timestamp with time zone |           | not null | now()
# Indexes:
#     "rental_pkey" PRIMARY KEY, btree (rental_id)
#     "idx_unq_rental_rental_date_inventory_id_customer_id" UNIQUE, btree (rental_date, inventory_id, customer_id)
# ...

# %%
# !psql -c "\d pagila.staff"
# Out:
#                                               Table "pagila.staff"
#    Column    |           Type           | Collation | Nullable |                    Default
# -------------+--------------------------+-----------+----------+------------------------------------------------
#  staff_id    | integer                  |           | not null | nextval('pagila.staff_staff_id_seq'::regclass)
#  first_name  | text                     |           | not null |
#  last_name   | text                     |           | not null |
#  address_id  | smallint                 |           | not null |
#  email       | text                     |           |          |
#  store_id    | smallint                 |           | not null |
#  active      | boolean                  |           | not null | true
#  username    | text                     |           | not null |
#  password    | text                     |           |          |
# ...

# %%
# !psql -c "\d pagila.store"
# Out:
#                                                 Table "pagila.store"
#       Column      |           Type           | Collation | Nullable |                    Default
# ------------------+--------------------------+-----------+----------+------------------------------------------------
#  store_id         | integer                  |           | not null | nextval('pagila.store_store_id_seq'::regclass)
#  manager_staff_id | smallint                 |           | not null |
#  address_id       | smallint                 |           | not null |
#  last_update      | timestamp with time zone |           | not null | now()
# Indexes:
#     "store_pkey" PRIMARY KEY, btree (store_id)
#     "idx_unq_manager_staff_id" UNIQUE, btree (manager_staff_id)
# Foreign-key constraints:
#     "store_address_id_fkey" FOREIGN KEY (address_id) REFERENCES pagila.address(address_id) ON UPDATE CASCADE ON DELETE RESTRICT
# Referenced by:
# ...

# %%
# !psql -c "SELECT pagila.film.film_id, title, category_id FROM pagila.film_category INNER JOIN pagila.film ON pagila.film.film_id = pagila.film_category.film_id WHERE title LIKE ‘%e’ ORDER BY title;"
# Out:
# psql: warning: extra command-line argument "category_id" ignored
# psql: warning: extra command-line argument "FROM" ignored
# psql: warning: extra command-line argument "pagila.film_category" ignored
# psql: warning: extra command-line argument "INNER" ignored
# psql: warning: extra command-line argument "JOIN" ignored
# psql: warning: extra command-line argument "pagila.film" ignored
# psql: warning: extra command-line argument "ON" ignored
# psql: warning: extra command-line argument "pagila.film.film_id" ignored
# psql: warning: extra command-line argument "=" ignored
# psql: warning: extra command-line argument "pagila.film_category.film_id" ignored
# psql: warning: extra command-line argument "WHERE" ignored
# psql: warning: extra command-line argument "title" ignored
# psql: warning: extra command-line argument "LIKE" ignored
# psql: warning: extra command-line argument "‘%e’" ignored
# psql: warning: extra command-line argument "ORDER" ignored
# ...

# %%
# !psql -c "SELECT pagila.film.film_id, title, category_id FROM pagila.film_category INNER JOIN pagila.film ON pagila.film.film_id = pagila.film_category.film_id WHERE title LIKE '%e' ORDER BY title;"
# Out:
# ERROR:  column "‘" does not exist
# LINE 1: ...d = pagila.film_category.film_id WHERE title LIKE ‘%e’ ORDER...
#                                                              ^

# %% [markdown]
# 2/11/2021
# Returns the columns film_id, title, and category_id for records that have a matching film_id in the tables film and film_category and where the title from the film table ends with an ‘e’. Furthermore, this query is ordered by title.

# %%
# !psql -c "SELECT pagila.film.film_id, title, category_id FROM pagila.film_category INNER JOIN pagila.film ON pagila.film.film_id = pagila.film_category.film_id WHERE title LIKE '%e' ORDER BY title;"
# Out:
#  film_id | title | category_id
# ---------+-------+-------------
# (0 rows)

# %% [markdown]
# 2/11/2021
# Returns columns address_id, first_name, and last_name for records that have a matching address_id in the tables staff and store and where the first_name from the staff table starts with an a. Furthermore, this query is ordered by last_name.

# %%
# !psql -c "SELECT pagila.staff.address_id, first_name, last_name FROM pagila.store INNER JOIN pagila.staff ON pagila.staff.address_id = pagila.store.address_id WHERE first_name LIKE 'a%' ORDER BY last_name;"
# Out:
#  address_id | first_name | last_name
# ------------+------------+-----------
# (0 rows)

# %% [markdown]
# 2/11/2021
# Returns columns inventory_id, film_id, and rental_date for records that have a matching inventory_id in the tables inventory and rental and where the film_id equals 1. Furthermore, this query is ordered by the rental tables inventory_id.

# %%
# !psql -c "SELECT pagila.rental.inventory_id, film_id, rental_date FROM pagila.inventory INNER JOIN pagila.rental ON pagila.rental.inventory_id = pagila.inventory.inventory_id WHERE  film_id = 1 ORDER BY pagila.rental.inventory_id;"
# Out:
#  inventory_id | film_id |      rental_date
# --------------+---------+------------------------
#             1 |       1 | 2005-07-08 19:03:15+00
#             1 |       1 | 2005-08-02 20:13:10+00
#             1 |       1 | 2005-08-21 21:27:43+00
#             2 |       1 | 2005-05-30 20:21:07+00
#             2 |       1 | 2005-06-17 20:24:00+00
#             2 |       1 | 2005-07-07 10:41:31+00
#             2 |       1 | 2005-07-30 22:02:34+00
#             2 |       1 | 2005-08-23 01:01:01+00
#             3 |       1 | 2005-07-31 21:36:07+00
#             3 |       1 | 2005-08-22 23:56:37+00
#             4 |       1 | 2005-08-02 00:47:19+00
#             4 |       1 | 2005-08-21 18:32:42+00
#             6 |       1 | 2005-05-27 07:03:28+00
#             6 |       1 | 2005-06-21 00:30:26+00
#             6 |       1 | 2005-07-07 20:59:06+00
#             6 |       1 | 2005-07-27 07:51:11+00
#             6 |       1 | 2005-08-21 00:30:32+00
# ...

# %% [markdown]
# 2/11/2021
# Returns all records from rental and only corresponding rows from staff when a row in the staff table has a first_name that starts with ‘a’. Furthermore, this query is ordered by last_name from the staff table.

# %%
# !psql -c "SELECT pagila.staff.staff_id, first_name, last_name FROM pagila.rental LEFT OUTER JOIN pagila.staff ON pagila.rental.staff_id = pagila.staff.staff_id WHERE  first_name LIKE 'a%' ORDER BY last_name;"
# Out:
#  staff_id | first_name | last_name
# ----------+------------+-----------
# (0 rows)

# %% [markdown]
# 2/11/2021
# Returns all records from staff and only corresponding rows from rental when a row in the staff table has a first_name that starts with ‘a’. Furthermore, this query is ordered by first_name from the staff table.

# %%
# !psql -c "SELECT pagila.staff.staff_id, first_name, last_name FROM pagila.rental RIGHT OUTER JOIN pagila.staff ON pagila.rental.staff_id = pagila.staff.staff_id WHERE  first_name LIKE 'a%' ORDER BY first_name;"
# Out:
#  staff_id | first_name | last_name
# ----------+------------+-----------
# (0 rows)

# %%
# !psql -c "SELECT pagila.film.film_id, title, category_id FROM pagila.film_category FULL OUTER JOIN pagila.film ON pagila.film.film_id = pagila.film_category.film_id WHERE title LIKE '%e' ORDER BY title;"
# Out:
#  film_id | title | category_id
# ---------+-------+-------------
# (0 rows)

# %% [markdown]
# 2/11/2021
# Returns the columns first_name and last_name from the customer table where the customer_id equals the store_id. Furthermore, this query is ordered by the variable CustomerName, which is defined as the customer’s first and last name.

# %%
# !psql -c "USE pagila SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM customer AS s LEFT OUTER JOIN customer AS c;"
# Out:
# ERROR:  syntax error at or near "USE"
# LINE 1: USE pagila SELECT s.first_name + ‘ ‘ + s.last_name AS StoreN...
#         ^

# %%
# !psql -c "SELECT pagila.customer.first_name + ' ' + pagila.customer.last_name AS StoreName, pagila.customer.first_name + ' ' + pagila.customer.last_name AS CustomerName FROM customer LEFT OUTER JOIN customer;"
# Out:
# ERROR:  syntax error at end of input
# LINE 1: ...ustomerName FROM customer AS s LEFT OUTER JOIN customer AS c
#                                                                        ^

# %%
# !psql -c "SELECT pagila.customer.first_name + ' ' + pagila.customer.last_name AS StoreName, pagila.customer.first_name + ' ' + pagila.customer.last_name AS CustomerName FROM customer LEFT OUTER JOIN customer ON s.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  syntax error at or near ";"
# LINE 1: ...name AS CustomerName FROM customer LEFT OUTER JOIN customer;
#                                                                       ^

# %%
# !psql -c "USE pagila SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM customer AS s LEFT OUTER JOIN customer AS c ON s.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  syntax error at or near "USE"
# LINE 1: USE pagila SELECT s.first_name + ' ' + s.last_name AS StoreN...
#         ^

# %%
# !psql -c "SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM customer AS s LEFT OUTER JOIN customer AS c ON s.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  relation "customer" does not exist
# LINE 1: ...rst_name + ' ' + c.last_name AS CustomerName FROM customer A...
#                                                              ^

# %%
# !psql -c "SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN customer AS c ON s.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  syntax error at or near "USE"
# LINE 1: USE pagila SELECT s.first_name + ' ' + s.last_name AS StoreN...
#         ^

# %%
# !psql -c "SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN pagila.customer AS c ON s.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  relation "customer" does not exist
# LINE 1: ...merName FROM pagila.customer AS s LEFT OUTER JOIN customer A...
#                                                              ^

# %%
# !psql -c "SELECT customer.first_name + ' ' + customer.last_name AS StoreName, customer.first_name + ' ' + customer.last_name AS CustomerName FROM pagila.customer LEFT OUTER JOIN pagila.customer ON s.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  operator does not exist: text + unknown
# LINE 1: SELECT s.first_name + ' ' + s.last_name AS StoreName, c.firs...
#                             ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.

# %%
# !psql -c "SELECT customer.first_name + ' ' + customer.last_name AS StoreName, customer.first_name + ' ' + customer.last_name AS CustomerName FROM pagila.customer LEFT OUTER JOIN customer ON s.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  table name "customer" specified more than once

# %%
# !psql -c "SELECT customer.first_name + ' ' + customer.last_name AS StoreName, customer.first_name + ' ' + customer.last_name AS CustomerName FROM pagila.customer LEFT OUTER JOIN customer ON customer.customer_id = customer.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  relation "customer" does not exist
# LINE 1: ...CustomerName FROM pagila.customer LEFT OUTER JOIN customer O...
#                                                              ^

# %%
# !psql -c "SELECT customer.first_name + ' ' + customer.last_name AS StoreName, customer.first_name + ' ' + customer.last_name AS CustomerName FROM pagila.customer LEFT OUTER JOIN customer ON customer.customer_id = customer.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  relation "customer" does not exist
# LINE 1: ...CustomerName FROM pagila.customer LEFT OUTER JOIN customer O...
#                                                              ^

# %%
# !psql -c "SELECT first_name + ' ' + last_name AS StoreName, first_name + ' ' + last_name AS CustomerName FROM pagila.customer LEFT OUTER JOIN pagila.customer ON customer.customer_id = customer.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  table name "customer" specified more than once

# %%
# !psql -c "SELECT first_name + ' ' + last_name AS StoreName, first_name + ' ' + last_name AS CustomerName FROM pagila.customer LEFT OUTER JOIN customer ON customer.customer_id = customer.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  table name "customer" specified more than once

# %%
# !psql -c "SELECT first_name + ' ' + last_name AS StoreName, first_name + ' ' + last_name AS CustomerName FROM pagila.customer LEFT OUTER JOIN pagila.customer ON customer_id = store_id ORDER BY CustomerName;"
# Out:
# ERROR:  relation "customer" does not exist
# LINE 1: ...CustomerName FROM pagila.customer LEFT OUTER JOIN customer O...
#                                                              ^

# %%
# !psql -c "SELECT first_name + ' ' + last_name AS StoreName, first_name + ' ' + last_name AS CustomerName FROM customer LEFT OUTER JOIN pagila.customer ON customer_id = store_id ORDER BY CustomerName;"
# Out:
# ERROR:  table name "customer" specified more than once

# %%
# !psql -c "SELECT first_name + ' ' + last_name AS StoreName, first_name + ' ' + last_name AS CustomerName FROM pagila.customer LEFT OUTER JOIN pagila.customer ON customer_id = store_id ORDER BY CustomerName;"
# Out:
# ERROR:  relation "customer" does not exist
# LINE 1: ...first_name + ' ' + last_name AS CustomerName FROM customer L...
#                                                              ^

# %%
# !psql -c "SELECT first_name + ' ' + last_name, first_name + ' ' + last_name AS CustomerName FROM pagila.customer LEFT OUTER JOIN pagila.customer ON customer_id = store_id ORDER BY CustomerName;"
# Out:
# ERROR:  table name "customer" specified more than once

# %%
# !psql -c "SELECT first_name + ' ' + last_name, first_name + ' ' + last_name AS CustomerName FROM pagila.customer AS c LEFT OUTER JOIN pagila.customer ON customer_id = store_id ORDER BY CustomerName;"
# Out:
# ERROR:  table name "customer" specified more than once

# %%
# !psql -c "SELECT first_name + ' ' + last_name, first_name + ' ' + last_name AS CustomerName FROM pagila.customer AS c LEFT OUTER JOIN pagila.customer ON c.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  column reference "customer_id" is ambiguous
# LINE 1: ....customer AS c LEFT OUTER JOIN pagila.customer ON customer_i...
#                                                              ^

# %%
# !psql -c "SELECT c.first_name + ' ' + c.last_name, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS c LEFT OUTER JOIN pagila.customer ON c.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  column reference "first_name" is ambiguous
# LINE 1: SELECT first_name + ' ' + last_name, first_name + ' ' + last...
#                ^

# %%
# !psql -c "SELECT c.first_name + c.last_name, c.first_name + c.last_name AS CustomerName FROM pagila.customer AS c LEFT OUTER JOIN pagila.customer ON c.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  operator does not exist: text + unknown
# LINE 1: SELECT c.first_name + ' ' + c.last_name, c.first_name + ' ' ...
#                             ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.

# %%
# !psql -c "SELECT c.first_name + c.last_name, c.first_name + c.last_name AS CustomerName FROM pagila.customer AS c LEFT OUTER JOIN pagila.customer ON c.customer_id = c.store_id ORDER BY CustomerName;"
# Out:
# ERROR:  operator does not exist: text + text
# LINE 1: SELECT c.first_name + c.last_name, c.first_name + c.last_nam...
#                             ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.

# %%
# !psql -c "SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM customer AS s LEFT OUTER JOIN customer AS c ON s.customer_id = c.store_id;"
# Out:
# ERROR:  syntax error at or near "USE"
# LINE 1: USE pagila SELECT s.first_name + ' ' + s.last_name AS StoreN...
#         ^

# %%
# !psql -c "SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN customer AS c ON s.customer_id = c.store_id;"
# Out:
# ERROR:  relation "customer" does not exist
# LINE 1: ...rst_name + ' ' + c.last_name AS CustomerName FROM customer A...
#                                                              ^

# %%
# !psql -c "SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN s AS c ON s.customer_id = c.store_id;"
# Out:
# ERROR:  relation "customer" does not exist
# LINE 1: ...merName FROM pagila.customer AS s LEFT OUTER JOIN customer A...
#                                                              ^

# %%
# Out:
# ERROR:  relation "s" does not exist
# LINE 1: ...merName FROM pagila.customer AS s LEFT OUTER JOIN s AS c ON ...
#                                                              ^

# %%
# !psql -c "SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN customer AS c ON s.customer_id = c.store_id;"
# Out:
# ERROR:  relation "customer" does not exist
# LINE 1: ...merName FROM pagila.customer AS s LEFT OUTER JOIN customer A...
#                                                              ^

# %%
# !psql -c "SELECT s.first_name + " " + s.last_name AS StoreName, c.first_name + " " + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN pagila.customer AS c ON s.customer_id = c.store_id;"
# Out:
# ERROR:  operator does not exist: text + unknown
# LINE 1: SELECT s.first_name + ' ' + s.last_name AS StoreName, c.firs...
#                             ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.

# %%
# !psql -c "SELECT s.first_name + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN pagila.customer AS c ON s.customer_id = c.store_id;"
# Out:
# psql: FATAL:  password authentication failed for user " + c.last_name AS CustomerName FROM pagila.customer AS s LEFT O"
# FATAL:  password authentication failed for user " + c.last_name AS CustomerName FROM pagila.customer AS s LEFT O"

# %%
# !psql -c "SELECT CAST(s.first_name AS text) + ' ' + s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN pagila.customer AS c ON s.customer_id = c.store_id;"
# Out:
# ERROR:  operator does not exist: text + unknown
# LINE 1: SELECT s.first_name + ' ' + s.last_name AS StoreName, c.firs...
#                             ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.

# %%
# !psql -c "SELECT s.first_name s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN pagila.customer AS c ON s.customer_id = c.store_id;"
# Out:
# ERROR:  operator does not exist: text + unknown
# LINE 1: SELECT CAST(s.first_name AS text) + ' ' + s.last_name AS Sto...
#                                           ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.

# %%
# !psql -c "SELECT s.first_name, s.last_name AS StoreName, c.first_name + ' ' + c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN pagila.customer AS c ON s.customer_id = c.store_id;"
# Out:
# ERROR:  syntax error at or near "."
# LINE 1: SELECT s.first_name s.last_name AS StoreName, c.first_name +...
#                              ^

# %%
# !psql -c "SELECT s.first_name, s.last_name AS StoreName, c.first_name, c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN pagila.customer AS c ON s.customer_id = c.store_id;"
# Out:
# ERROR:  operator does not exist: text + unknown
# LINE 1: ...irst_name, s.last_name AS StoreName, c.first_name + ' ' + c....
#                                                              ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.

# %% [markdown]
# 2/11/2021
# Returns the columns of film_id, title, and category_id for all records from the film table and all records from the film_category table where the title from the film table ends with an ‘e’. Where there isn’t a matching row in either table, there are null values. Furthermore, this query is ordered by the title from the film table.

# %%
# !psql -c "SELECT s.first_name, s.last_name AS StoreName, c.first_name, c.last_name AS CustomerName FROM pagila.customer AS s LEFT OUTER JOIN pagila.customer AS c ON s.customer_id = c.store_id;"
# Out:
#  first_name  |  storename   | first_name  | customername
# -------------+--------------+-------------+--------------
#  MARY        | SMITH        | MARY        | SMITH
#  MARY        | SMITH        | PATRICIA    | JOHNSON
#  MARY        | SMITH        | LINDA       | WILLIAMS
#  PATRICIA    | JOHNSON      | BARBARA     | JONES
#  MARY        | SMITH        | ELIZABETH   | BROWN
#  PATRICIA    | JOHNSON      | JENNIFER    | DAVIS
#  MARY        | SMITH        | MARIA       | MILLER
#  PATRICIA    | JOHNSON      | SUSAN       | WILSON
#  PATRICIA    | JOHNSON      | MARGARET    | MOORE
#  MARY        | SMITH        | DOROTHY     | TAYLOR
#  PATRICIA    | JOHNSON      | LISA        | ANDERSON
#  MARY        | SMITH        | NANCY       | THOMAS
#  PATRICIA    | JOHNSON      | KAREN       | JACKSON
#  PATRICIA    | JOHNSON      | BETTY       | WHITE
#  MARY        | SMITH        | HELEN       | HARRIS
#  PATRICIA    | JOHNSON      | SANDRA      | MARTIN
# ...
